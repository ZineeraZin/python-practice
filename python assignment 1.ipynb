# %% [markdown]
# # Python Assignment 1
# ## Data Structures - Strings & Tuples
#
# Name: Zineera

# %%
string1 = "Hello "
name = input("Enter your Name: ")

string2 = string1 + name

print(string2)
# Out:
# Enter your Name:  zara
# Hello zara

# %%
string3 = ", welcome to Python programming"

string2 = string2 + string3

print(string2)
# Out:
# Hello zara, welcome to Python programming

# %%
print("First character:", string2[0])
# Out:
# First character: H

# %%
print("Last character:", string2[-1])
# Out:
# Last character: g

# %%
print("First 5 characters:", string2[:5])
# Out:
# First 5 characters: Hello

# %%
print("Last 11 characters:", string2[-11:])
# Out:
# Last 11 characters: programming

# %%
print("Reverse:", string2[::-1])
# Out:
# Reverse: gnimmargorp nohtyP ot emoclew ,araz olleH

# %%
print("Python:", string2[21:27])
# Out:
# Python: o Pyth

# %%
start = string2.index("Python")
print("Python:", string2[start:start + 6])
# Out:
# Python: Python

# %%
strM = "Python beginner tutorial"

print(strM)
# Out:
# Python beginner tutorial

# %%
print(strM.upper())
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
print(strM.lower())
# Out:
# python beginner tutorial

# %%
print(strM.capitalize())
# Out:
# Python beginner tutorial

# %%
print("Number of 't' characters:", strM.count("t"))
# Out:
# Number of 't' characters: 3

# %%
new_string = strM.replace("Python", "Machine Learning")

print(new_string)
# Out:
# Machine Learning beginner tutorial

# %%
(10, 20, 30)
# Out:
# (10, 20, 30)

# %%
t1 = (10, 20, 30)
t2 = (40, 50, 60)

print("First tuple:", t1)
print("Second tuple:", t2)
# Out:
# First tuple: (10, 20, 30)
# Second tuple: (40, 50, 60)

# %%
t_combine = t1 + t2

print("Combined tuple:", t_combine)
# Out:
# Combined tuple: (10, 20, 30, 40, 50, 60)

# %%
t_repeat = t_combine * 3

print("Repeated tuple:", t_repeat)
# Out:
# Repeated tuple: (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print("Third element:", t_combine[2])
# Out:
# Third element: 30

# %%
t_combine[2]
# Out:
# 30

# %%
print("First three elements:", t_combine[:3])
# Out:
# First three elements: (10, 20, 30)

# %%
print("Last three elements:", t_combine[-3:])
# Out:
# Last three elements: (40, 50, 60)
